# %% [markdown]
# Q.1) In the below elements which of them are values or an expression? eg:- values can be
# integer or string and expressions will be mathematical operators.
#
# ANS:
#
#    1)VALUES : 'hello' ,-87.8 ,6
#    2)EXPRESSONS : -  ,  +  ,  /  , *
#
#
# Q.2)2. What is the difference between string and variable?
#
# ANS:
#
#     A string is a sequence of characters, such as "hello" or "goodbye", It is inmutable.
#
#     In programming, a variable is used to hold a value, which can be changed, while a string is used to hold     a sequence of characters, which cannot be changed.
#
#
# Q.3. Describe three different data types.
#
#  ANS:
#
#     1) Integer: An integer is a whole number, such as 1, 2, or -5. It can be positive or negative and has no        decimal point. It can be used to represent numerical values.
#
#     2) String: A string is a sequence of characters, such as "hello" or "goodbye". It is enclosed in               quotation marks ,either single or double. It can be used to represent textual data
#
#
#     3) Float: A float, short for "floating-point number," is a number with a decimal point, such as 3.14 or       -0.01. It can be used to represent decimal numbers and scientific notation.
#       In Python, it's also possible to use complex numbers, lists, dictionaries, etc as data types.
#
#
# Q.4
#
# ANS:
#
#      1)  in Python, an expression is made up of one or more values, variables, and operators. For example, 2         2+3,"hello" + "world", or x * y.
#      2) All expressions in Python evaluate to a single value. This means that the interpreter will take the        expression and return a single value such as a number, string or boolean. For example, the expression        2+3 will evaluate to the value 5, and the expression "hello" + "world" will evaluate to the string             "hello world". The value returned by an expression can be assigned to a variable, used as an               argument in a function, or printed to the screen.
#
#  Q.5) This assignment statements, like spam = 10. What is the difference between an
#  expression and a statement?
#
#  ANS:
#
#     1)An expression is a combination of values, variables, and operators that evaluates to a single value.       for example, 2 + 3, "hello" + "world", or x * y are all expressions.
#
#     2)A statement, on the other hand, is a command or instruction that tells the computer to perform a            specific action or task. An assignment statement, like spam = 10, is a type of statement that assigns a      value to a variable. In this case, the value 10 is being assigned to the variable "spam".
#
#     3)  Another example of a statement is a function call, like print("hello world"). In this case, the           is telling the computer to execute the function print() and pass in the string "hello world" as an            argument.
#
#     4)In summary, an expression is a combination of values, variables, and operators that evaluates to a         single value, while a statement is a command or instruction that tells the computer to perform a              action or task.
#
# Q.6)  After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1
#
#
# ANS:
#
#
#     After running the code, the variable bacon will contain the value 22. The statement bacon + 1 is an         expression that evaluates to the value 23, but it is not assigned to the variable bacon. So the value of     bacon remains 22.If WE want to update the value of bacon, you would have to re-assign it like this:         bacon = bacon + 1
#
#
# Q.7) What should the values of the following two terms
#
# 1.'spam' + 'spamspam'
# 2.'spam' * 3
#
# ANS:
#
#    1)The value of the expression 'spam'+'spamspam' would be 'spamspamspam'. This is because the + operator      is    used to concatenate strings, meaning it combines two strings together to form a new string. In this    case,    the string 'spam' is being concatenated with the string 'spamspam', resulting in the new string    'spamspamspam'.
#
#    2)In python, when a string is multiplied with an integer, it creates a new string by concatenating the        original string that number of times. So 'spam'*3 will create a new string by concatenating 'spam'          three times.
#
#
# Q.8) Why is eggs a valid variable name while 100 is invalid?
# ANS:
#
#      In Python, variable names can consist of letters, numbers, and underscores, but they cannot start with      a number. This is because Python uses the first character of a variable name to determine if it's a          variable or a number.
#
#     "eggs" is a valid variable name because it starts with a letter.
#
#      On the other hand, "100" is not a valid variable name because it starts with a number, and it would be        interpreted as an integer rather than a variable name.
#
# Q.9) What three functions can be used to get the integer, floating-point number, or string
# version of a value?
# ANS:
#
#     In Python, there are three built-in functions that can be used to get the integer, floating-point           number, or string version of a value:
#
#        1)int() - This function can be used to convert a value to an integer. For example, int(3.14) will              return the integer value 3.
#
#        2)float() - This function can be used to convert a value to a floating-point number. For example,              float(5) will return the value 5.0, which is a floating-point number.
#
#       3)str() - This function can be used to convert a value to a string. For example, str(5) will return           the string value "5".
#
# Q.10) Why does this expression cause an error? How can you fix it?
#       'I have eaten' + 99 + 'burritos.'
#
#     1) This expression causes an error because we are trying to concatenate a string and an integer without       any explicit type casting. The + operator is used for both addition and concatenation in Python, but         when it is used to concatenate a string and an integer, it throws an error.
#
#      2) To fix this, we would need to convert the integer 99 to a string using the str() function, like          this:
#
#          'I have eaten ' + str(99) + ' burritos.'
